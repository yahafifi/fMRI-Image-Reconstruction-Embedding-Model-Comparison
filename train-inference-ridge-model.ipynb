# %%
# !git clone https://github.com/yahafifi/fMRI-Image-Reconstruction-Embedding-Model-Comparison.git
# Out:
# Cloning into 'fMRI-Image-Reconstruction-Embedding-Model-Comparison'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 33 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 36.75 KiB | 4.59 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd fMRI-Image-Reconstruction-Embedding-Model-Comparison
# Out:
# /kaggle/working/fMRI-Image-Reconstruction-Embedding-Model-Comparison

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-install-b7548o5v/clip_eb8ed77592484d2f90639f777011f6f5
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-install-b7548o5v/clip_eb8ed77592484d2f90639f777011f6f5
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.6/127.6 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 524.8 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 15.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369489 sha256=04e6e18d1b4180c10055e0d10a46cb07aa4f929e05948191d7e2979c80ef3473
# ...

# %%
# !python run_experiment.py --model_name resnet50 --download --visualize
# Out:
# Using device: cuda
# Output base path: /kaggle/working/output
# 2025-03-30 23:07:20.673244: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-30 23:07:20.916401: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-30 23:07:20.994394: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# --- Starting Experiment for Embedding Model: RESNET50 ---
# --- Starting Data Download and Setup ---
# ...
# File downloaded and saved at: /kaggle/working/data/fMRI/GOD/Subject3.h5
# ...
# File downloaded and saved at: /kaggle/working/data/fMRI/imagenet/images/image_stimuli.zip
# ...

# %%
# !python run_experiment.py --model_name clip --visualize
# Out:
# Using device: cuda
# Output base path: /kaggle/working/output
# 2025-03-30 23:31:59.568917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-30 23:31:59.591038: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-30 23:31:59.597648: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# --- Starting Experiment for Embedding Model: CLIP ---
#
# --- Loading GOD fMRI Data ---
# Loading fMRI data for Subject 3, ROI: ROI_VC
# Loaded 3450 samples, 4643 voxels.
# Applying run-wise normalization (scaling)...
# Normalization complete.
# ...

# %%
# !python run_experiment.py --model_name vit --visualize
# Out:
# Using device: cuda
# Output base path: /kaggle/working/output
# 2025-03-30 23:58:08.361041: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-30 23:58:08.382628: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-30 23:58:08.389261: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# --- Starting Experiment for Embedding Model: VIT ---
#
# --- Loading GOD fMRI Data ---
# Loading fMRI data for Subject 3, ROI: ROI_VC
# Loaded 3450 samples, 4643 voxels.
# Applying run-wise normalization (scaling)...
# Normalization complete.
# Averaging test data across 50 unique stimuli...
# ...
